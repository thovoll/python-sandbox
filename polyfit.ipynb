# %%
import numpy as np
import numpy.polynomial.polynomial as poly
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1, 51)
print(x)
# Out:
# [0.   0.02 0.04 0.06 0.08 0.1  0.12 0.14 0.16 0.18 0.2  0.22 0.24 0.26
#  0.28 0.3  0.32 0.34 0.36 0.38 0.4  0.42 0.44 0.46 0.48 0.5  0.52 0.54
#  0.56 0.58 0.6  0.62 0.64 0.66 0.68 0.7  0.72 0.74 0.76 0.78 0.8  0.82
#  0.84 0.86 0.88 0.9  0.92 0.94 0.96 0.98 1.  ]

# %%
y = x**3 - x + (np.random.randn(len(x)) / 10)
# y = x**2
print(y)
# Out:
# [ 0.25620601  0.18317589 -0.08203669 -0.01504512 -0.06905514 -0.23613634
#  -0.14344828 -0.12503861 -0.35070212 -0.09406908 -0.12641446 -0.09004932
#  -0.11121206 -0.18993045 -0.23925263 -0.32645358 -0.27946333 -0.36878381
#  -0.32202738 -0.25730866 -0.49404884 -0.3362768  -0.30242181 -0.28750595
#  -0.21475223 -0.22512492 -0.46735156 -0.37352619 -0.22530197 -0.42415763
#  -0.46978551 -0.23709013 -0.39734372 -0.33058553 -0.34965767 -0.31758718
#  -0.26963269 -0.22959864 -0.22536327 -0.46512257 -0.39287328 -0.23623261
#  -0.24823965 -0.29493279 -0.32602054 -0.0339842  -0.08657287 -0.14271657
#  -0.25861467  0.06964671  0.04311349]

# %%
c, stats = poly.polyfit(x, y, 3, full=True)
yt = c[0] + c[1]*x + c[2]*x**2 + c[3]*x**3

# c, stats = P.polyfit(x,y,2,full=True)
# yt = c[0] + c[1]*x + c[2]*x**2

# %%
plt.figure(1)
plt.subplot(211)
plt.plot(x, y)

plt.subplot(212)
plt.plot(x, yt)
plt.show()
